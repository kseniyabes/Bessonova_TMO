# %% [markdown]
# # Data description
# The data is the results of a chemical analysis of wines grown
# in the same region in Italy by three different cultivators.
# There are thirteen different measurements taken for different constituents found in the three types of wine.

# %% [markdown]
# # Library import

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import *
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
sns.set(style="ticks")

# %% [markdown]
# # Transform data to Pandas

# %%
def make_dataframe(ds_function):
    ds = ds_function()
    df = pd.DataFrame(data= np.c_[ds['data'], ds['target']],
                     columns= list(ds['feature_names']) + ['target'])
    return df

# %% [markdown]
# # 2. Information about data

# %%
data = make_dataframe(load_wine)
data.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %%
#Размер датасета
data.shape
total_count = data.shape[0]
print('Всего строк: {}'.format(total_count))
total_count = data.shape[1]
print('Всего столбов: {}'.format(total_count))
# Out:
# Всего строк: 178
# Всего столбов: 14

# %%
# Основные статистические характеристки набора данных
data.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
data['nonflavanoid_phenols'].unique()
# Out:
# array([0.28, 0.26, 0.3 , 0.24, 0.39, 0.34, 0.31, 0.29, 0.22, 0.43, 0.33,
#        0.4 , 0.32, 0.17, 0.25, 0.27, 0.47, 0.37, 0.42, 0.5 , 0.2 , 0.21,
#        0.19, 0.63, 0.53, 0.45, 0.55, 0.14, 0.13, 0.35, 0.61, 0.48, 0.52,
#        0.58, 0.66, 0.6 , 0.41, 0.44, 0.56])

# %% [markdown]
# # Visual research

# %% [markdown]
# ## Диаграмма рассеяния

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.scatterplot(data=data, x='alcohol', y='color_intensity', ax=ax)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='color_intensity'>

# %% [markdown]
# ## Гистограмма распределения

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.distplot(data['color_intensity'])
# Out:
# /home/anzhela/1cloud/1cloud/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='color_intensity', ylabel='Density'>

# %% [markdown]
# ## Парные графики

# %%
sns.jointplot(data=data, x='alcohol', y='color_intensity', kind="kde")

# %%
sns.jointplot(data=data, x='alcohol', y='color_intensity')

# %% [markdown]
# ## Парные диаграммы

# %%
sns.pairplot(data)

# %%
sns.pairplot(data, hue="od280/od315_of_diluted_wines")

# %% [markdown]
# ## Среднее отклонение признака

# %%
sns.boxplot(x=data['color_intensity'])
# Out:
# <AxesSubplot:xlabel='color_intensity'>

# %%
sns.violinplot(x=data['color_intensity'])
# Out:
# <AxesSubplot:xlabel='color_intensity'>

# %% [markdown]
# # Корреляция признаков

# %%
data.corr()
# Out:
#                                alcohol  malic_acid       ash  \
# alcohol                       1.000000    0.094397  0.211545
# malic_acid                    0.094397    1.000000  0.164045
# ash                           0.211545    0.164045  1.000000
# alcalinity_of_ash            -0.310235    0.288500  0.443367
# magnesium                     0.270798   -0.054575  0.286587
# total_phenols                 0.289101   -0.335167  0.128980
# flavanoids                    0.236815   -0.411007  0.115077
# nonflavanoid_phenols         -0.155929    0.292977  0.186230
# proanthocyanins               0.136698   -0.220746  0.009652
# color_intensity               0.546364    0.248985  0.258887
# hue                          -0.071747   -0.561296 -0.074667
# od280/od315_of_diluted_wines  0.072343   -0.368710  0.003911
# proline                       0.643720   -0.192011  0.223626
# target                       -0.328222    0.437776 -0.049643
#
# ...

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row', figsize=(10,5))
sns.heatmap(data.corr(), annot=True, fmt='.1f')
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(1, 1, sharex='col', sharey='row', figsize=(10,5))
mask = np.zeros_like(data.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(data.corr(), mask=mask, annot=True, fmt='.1f')
# Out:
# /tmp/ipykernel_31200/962350369.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(data.corr(), dtype=np.bool)
# <AxesSubplot:>
